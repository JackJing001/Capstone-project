# %%
import os
import subprocess
import gzip
import io
import json
import re
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
meta_list = []

with open('metadata/sample.jsonl', 'r') as json_file:
    json_list = list(json_file)

for json_str in json_list:
    result = json.loads(json_str)
    meta_list.append(result)
    
pdf_list = []
    
with open('pdf_parses/sample.jsonl', 'r') as json_file:
    json_list = list(json_file)

for json_str in json_list:
    result = json.loads(json_str)
    pdf_list.append(result)

# %%
df_meta = pd.DataFrame(meta_list)
df_meta = df_meta.set_index('paper_id')
df_meta.columns
# Out:
# Index(['title', 'authors', 'abstract', 'year', 'arxiv_id', 'acl_id', 'pmc_id',
#        'pubmed_id', 'doi', 'venue', 'journal', 'mag_id', 'mag_field_of_study',
#        'outbound_citations', 'inbound_citations', 'has_outbound_citations',
#        'has_inbound_citations', 'has_pdf_parse', 's2_url', 'has_pdf_body_text',
#        'has_pdf_parsed_abstract', 'has_pdf_parsed_body_text',
#        'has_pdf_parsed_bib_entries', 'has_pdf_parsed_ref_entries'],
#       dtype='object')

# %%
df_pdf = pd.DataFrame(pdf_list)
df_pdf = df_pdf.set_index('paper_id')
df_pdf.columns
# Out:
# Index(['_pdf_hash', 'abstract', 'body_text', 'bib_entries', 'ref_entries'], dtype='object')

# %%
# Collect title and abstract

df = pd.DataFrame(df_meta.loc[:, 'title'])
for i in df.index:
    if i in df_pdf.index:
        if df_pdf.at[i, 'abstract'] != [] and df_pdf.at[i, 'abstract'] != '':
            df.at[i, 'abstract'] = df_pdf.at[i, 'abstract'][0]['text']

df.replace('', np.nan, inplace=True)
df = df.dropna()

# Collect full text

for i in df.index:
    if i in df_pdf.index:
        full_text = ''
        for sec in df_pdf.loc[i,'body_text']:
            if sec['text'] != [] and sec['text'] != '':
                full_text += sec['text']
        df.at[i, 'full_text'] = df.loc[i, 'abstract'] + full_text
        
# Collect related work text
### WARNING: REPLACE 'introduction' with 'related_work'

for i in df.index:
    if i in df_pdf.index:
        related_work_text = ''
        for sec in df_pdf.loc[i,'body_text']:
            if sec['section'].lower() == 'introduction' and sec['text'] != '' and sec['text'] != []:
                related_work_text += sec['text']
        df.at[i, 'related_work_text'] = related_work_text
        
# Remove papers that don't have related work sections  
df['related_work_text'].replace('', np.nan, inplace=True)
df = df.dropna()
df.head(3)
# Out:
#                                                       title  \
# paper_id
# 94551546  Gd(III) ion-chelated supramolecular assemblies...
# 18981358  Rubber hand illusion induced by touching the f...
# 18982127                 GRAPHS WITH 4-STEINER CONVEX BALLS
#
#                                                    abstract  \
# paper_id
# 94551546  Ethanolamine (EA) or ethylenediamine (ED)-func...
# 18981358  Background: Studies in animals and humans indi...
# 18982127  Abstract. Recently a new graph convexity was i...
#
#                                                   full_text  \
# paper_id
# 94551546  Ethanolamine (EA) or ethylenediamine (ED)-func...
# 18981358  Background: Studies in animals and humans indi...
# 18982127  Abstract. Recently a new graph convexity was i...
#
#                                           related_work_text
# paper_id
# 94551546  Gene therapy holds potential for treating many...
# 18981358  Spinal cord injuries (SCI) cause an irreversib...
# 18982127  The study of abstract convexity began in the e...

# %%
# Find sentence-citataion pairs that have more than 10 words in the sentence

def find_pair(textl, bibl):
    pair_dict = {}
    for para in textl:
        cite_list = para['cite_spans']
        text = para['text']
        for cite in cite_list:
            start = int(cite['start'])
            end = int(cite['end'])
            # If cite_spans out of the sentence
            if text[start-2] in ['.', '!', '?']:
                i = start-3
                while i >= 0:
                    if text[i] in ['.', '!', '?']:
                        break
                    i = i - 1
                while i <= start-2:
                    if re.match("[A-Z]", text[i]) == None:
                        i = i + 1
                    else:
                        break
                sentence = text[i:start-1]
                sentence_len = len(sentence.split(' '))
                ref_id = cite['ref_id']
                paper_id = bibl[ref_id]['link']
                if paper_id != None and sentence_len >= 10:
                    pair_dict[paper_id] = sentence
                    
            # If cite_spans in the sentence
            if end + 1 < len(text):
                if text[end+1] in ['.', '!', '?']:
                    i = start-1
                    while i >= 0:
                        if text[i] in ['.', '!', '?']:
                            break
                        i = i - 1
                    while i <= start-2:
                        if re.match("[A-Z]", text[i]) == None:
                            i = i + 1
                        else:
                            break
                    sentence = text[i:end+2]
                    sentence_len = len(sentence.split(' '))
                    ref_id = cite['ref_id']
                    paper_id = bibl[ref_id]['link']
                    if paper_id != None and sentence_len >= 10:
                        pair_dict[paper_id] = sentence
    
    return pair_dict

# %%
# test find_pair function
test_text = df_pdf.at['18982127', 'body_text']
test_bib = df_pdf.at['18982127', 'bib_entries']
find_pair(test_text, test_bib)
# Out:
# {'6739367': 'For a more extensive study on this topic see [5] .',
#  '10259494': 'Such characterizations for the g-and m-convexity are given in [8] , for the g 3 -convexity in [12] and for the m-convexity in [4] .',
#  '12220557': 'It is not hard to see that graphs in which N [S] is convex for every convex set S ⊆ V are exactly the graphs in which N j [S] is convex for every convex set S ⊆ V and every j ≥ 1 in terms of any convexity in graphs, see [6] .'}

# %%
# Collect sentence-citation pairs in full text
for i in df.index:
    if i in df_pdf.index:
        textl = df_pdf.at[i, 'body_text']
        bibl = df_pdf.at[i, 'bib_entries']
        pair = find_pair(textl, bibl)
        df.at[i, 'full_text_pairs'] = i
        df.at[i, 'full_text_pairs'] = pair

# %%
df
# Out:
#                                                        title  \
# paper_id
# 94551546   Gd(III) ion-chelated supramolecular assemblies...
# 18981358   Rubber hand illusion induced by touching the f...
# 18982127                  GRAPHS WITH 4-STEINER CONVEX BALLS
# 18982460   A novel automatic regulatory device for contin...
# 18982504   ANALYTICAL MODELING AND ANALYSIS OF THROUGH SI...
# 18982781   The Del1 deposition domain can immobilize 3α-h...
# 18983391   Investigation ofant colonyalgorithm in multipl...
# 18985891   Global Morbidity and Mortality of Leptospirosi...
# 18986705   Duplicated rDNA sequences of variable lengths ...
# 18986901   HOW TO DEAL WITH THE ARROW OF TIME IN QUANTUM ...
# 18987532   Use of recombinant human growth hormone (rhGH)...
# 18987535   Two Clustering Diffusion Patterns Identified f...
# 18987990   Fragmentation Production of Ωccc and Ωbbb Baryons
# 18989350   Construction of a high-density, high-resolutio...
# 199662866  The Lipid Paradox Among Acute Ischemic Stroke ...
# 199665542  Static Klein–Gordon–Maxwell–Proca systems in 4...
# 199665735  In vivo/in vitro Studies of the Effects of the...
# 199668887  On gossip-based information dissemination in p...
# 199668943  3D Human Pose Estimation under limited supervi...
# 2870075    Calibration Method of an Ultrasonic System for...
# 2870145    Excessive Daytime Sleepiness Is Associated wit...
# 2870542    Understanding patient safety performance and e...
# 2872613    Dynamic Parameters of Balance Which Correlate ...
# 2873021    Scientific Workflow Systems for 21st Century e...
# 2874360    Occupational Radiation Exposure during Endosco...
# 2874531    Are We Spending Too Many Years in School? Caus...
# 2875387    Elsevier An improved least squares Laplacian p...
# 2877021        Necessity of noise in physiology and medicine
# 2877038    Swift: the missing link between peer-to-peer a...
# 2877272    Cone-beam CT angiography (Dyna CT) for intraop...
# 2877521    Conditional Density Estimation with Dimensiona...
# 2878408    Type 2 Diabetes Mellitus, Oral Diabetic Medica...
# 2879698    Determination of DPPH Radical Oxidation Caused...
# 2879848    Influence of galvanic vestibular stimulation o...
# 213466066  Aerodrome Warning Verification Using Quality M...
# 116985999  Reanalysis of near-infrared extragalactic back...
# 116987163  Understanding our Galaxy - key contributions f...
# 116988830  On No-Node Solutions of the Lazer-McKenna Susp...
# 118860172  Effect of a magnetic field on massive star win...
# 118861869  The Effect of General Relativistic Precession ...
# 118863510  A k-deformed Model of Growing Complex Networks...
# 118863857    Cosmic Ray Removal in Fiber Spectroscopic Image
# 118864086  Exceptional points in the thermoacoustic spectrum
# 118864492       Non-thermal emission from stellar bow shocks
# 118864667     A WISE Survey of Circumstellar Disks in Taurus
# 118866026  The semi-constrained NMSSM in light of muon g-...
# 84882469   The Effects of Different Hormones and their do...
#
#                                                     abstract  \
# paper_id
# 94551546   Ethanolamine (EA) or ethylenediamine (ED)-func...
# 18981358   Background: Studies in animals and humans indi...
# 18982127   Abstract. Recently a new graph convexity was i...
# 18982460   Background: Benign prostatic hyperplasia is a ...
# 18982504   Abstract-This paper gives a comprehensive stud...
# 18982781   Abstract Developing methods that result in tar...
# 18983391             The conventional approaches to routing
# 18985891                                          Background
# 18986705   We describe cloned segments of rDNA that conta...
# 18986901   Abstract The formalism of Quantum Mechanics is...
# 18987532   The activity of recombinant human growth hormo...
# 18987535   Abstract. This study analyzed the spatio-tempo...
# 18987990   The Λ baryons with a single heavy flavor which...
# 18989350   Construction of genetic linkage map is essenti...
# 199662866  Abstract: Background and objectives: The Studi...
# 199665542  Abstract. We prove existence and uniform bound...
# 199665735  Type II arabinogalactan (AG) is a polysacchari...
# 199668887  Pervasive computing systems employ distributed...
# 199668943  Estimating 3D human pose from monocular images...
# 2870075    System calibration is fundamental to the overa...
# 2870145    Excessive daytime sleepiness (EDS) is a ubiqui...
# 2870542    . (2016) Understanding patient safety performa...
# 2872613    Poor balance in older persons contributes to a...
# 2873021    With the advances in e-Sciences and the growin...
# 2874360    Objective. To evaluate the effectiveness of ra...
# 2874531    Die Dokumente auf EconStor dürfen zu eigenen w...
# 2875387    Abstract. This paper describes two ways of imp...
# 2877021    Noise is omnipresent in biomedical systems and...
# 2877038    A common pitfall of many proposals on new info...
# 2877272    Background Arteriovenous malformations (AVMs) ...
# 2877521    Regression aims at estimating the conditional ...
# 2878408    Breast cancer is among the most common cancers...
# 2879698    The demonstrated modified spectrophotometric m...
# 2879848    The vestibular system analyses angular and lin...
# 213466066  Improvement in Aerodrome Warning (AW) nowcasts...
# 116985999  We reanalyzed the data from the Infrared Teles...
# 116987163  Young massive stars, with their spectacular ma...
# 116988830  In this paper, we are concerned with the exist...
# 118860172  We generalize the Rigid-Field Hydrodynamic equ...
# 118861869  An eccentric nuclear disk consists of stars mo...
# 118863510  The Barabási-Bianconi (BB) fitness model can b...
# 118863857  Single-exposure spectra in large spectral surv...
# 118864086  Exceptional points are found in the spectrum o...
# 118864492  Since the detection of non-thermal radio emiss...
# 118864667  We have compiled photometry at 3.4, 4.6, 12 an...
# 118866026  Abstract: The semi-constrained NMSSM (scNMSSM)...
# 84882469   In this research, three different hormones and...
#
#                                                    full_text  \
# paper_id
# 94551546   Ethanolamine (EA) or ethylenediamine (ED)-func...
# 18981358   Background: Studies in animals and humans indi...
# 18982127   Abstract. Recently a new graph convexity was i...
# 18982460   Background: Benign prostatic hyperplasia is a ...
# 18982504   Abstract-This paper gives a comprehensive stud...
# 18982781   Abstract Developing methods that result in tar...
# 18983391   The conventional approaches to routing Traffic...
# 18985891   BackgroundLeptospirosis is a zoonotic bacteria...
# 18986705   We describe cloned segments of rDNA that conta...
# 18986901   Abstract The formalism of Quantum Mechanics is...
# 18987532   The activity of recombinant human growth hormo...
# 18987535   Abstract. This study analyzed the spatio-tempo...
# 18987990   The Λ baryons with a single heavy flavor which...
# 18989350   Construction of genetic linkage map is essenti...
# 199662866  Abstract: Background and objectives: The Studi...
# 199665542  Abstract. We prove existence and uniform bound...
# 199665735  Type II arabinogalactan (AG) is a polysacchari...
# 199668887  Pervasive computing systems employ distributed...
# 199668943  Estimating 3D human pose from monocular images...
# 2870075    System calibration is fundamental to the overa...
# 2870145    Excessive daytime sleepiness (EDS) is a ubiqui...
# 2870542    . (2016) Understanding patient safety performa...
# 2872613    Poor balance in older persons contributes to a...
# 2873021    With the advances in e-Sciences and the growin...
# 2874360    Objective. To evaluate the effectiveness of ra...
# 2874531    Die Dokumente auf EconStor dürfen zu eigenen w...
# 2875387    Abstract. This paper describes two ways of imp...
# 2877021    Noise is omnipresent in biomedical systems and...
# 2877038    A common pitfall of many proposals on new info...
# 2877272    Background Arteriovenous malformations (AVMs) ...
# 2877521    Regression aims at estimating the conditional ...
# 2878408    Breast cancer is among the most common cancers...
# 2879698    The demonstrated modified spectrophotometric m...
# 2879848    The vestibular system analyses angular and lin...
# 213466066  Improvement in Aerodrome Warning (AW) nowcasts...
# 116985999  We reanalyzed the data from the Infrared Teles...
# 116987163  Young massive stars, with their spectacular ma...
# 116988830  In this paper, we are concerned with the exist...
# 118860172  We generalize the Rigid-Field Hydrodynamic equ...
# 118861869  An eccentric nuclear disk consists of stars mo...
# 118863510  The Barabási-Bianconi (BB) fitness model can b...
# 118863857  Single-exposure spectra in large spectral surv...
# 118864086  Exceptional points are found in the spectrum o...
# 118864492  Since the detection of non-thermal radio emiss...
# 118864667  We have compiled photometry at 3.4, 4.6, 12 an...
# 118866026  Abstract: The semi-constrained NMSSM (scNMSSM)...
# 84882469   In this research, three different hormones and...
#
#                                            related_work_text  \
# paper_id
# 94551546   Gene therapy holds potential for treating many...
# 18981358   Spinal cord injuries (SCI) cause an irreversib...
# 18982127   The study of abstract convexity began in the e...
# 18982460   Benign prostatic hyperplasia (BPH) is a common...
# 18982504   Three-dimensional integrated circuits (3D ICs)...
# 18982781   Mouse Del1 is an ECM protein secreted by embry...
# 18983391   Traffic engineering is one of the active resea...
# 18985891   Leptospirosis is a zoonotic bacterial disease ...
# 18986705   The rDNA of Drosophila melanogaster can contai...
# 18986901   The formalism of Quantum Mechanics (QM) is bas...
# 18987532   Mobilized peripheral blood progenitor cells (P...
# 18987535   In the last few decades, there have been an in...
# 18987990   The quark model of hadrons has proved to be su...
# 18989350   Genetic linkage maps are essential for the und...
# 199662866  Hypercholesterolemia is a well-documented risk...
# 199665542  Static Klein-Gordon-Maxwell-Proca systems are ...
# 199665735  Maytenus ilicifolia, a plant popularly known i...
# 199668887  Nowadays, the possibility to collect, store, a...
# 199668943  Over the years, the performance of monocular 3...
# 2870075    Ultrasonic temperature measurement, as a non-i...
# 2870145    Inadequate sleep is a pervasive problem in tod...
# 2870542    As the patient safety agenda has evolved in pr...
# 2872613    Incidence of falls escalates with age, events ...
# 2873021    Scientific workflow has become increasingly po...
# 2874360    Techniques related to endoscopic retrograde ch...
# 2874531    The enactment of educational policies designed...
# 2875387    Multi-resolution data representations are beco...
# 2877021    Albert Einstein discovered noise accidentally ...
# 2877038    In this paper, we introduce Swift protocol. Sw...
# 2877272    Arteriovenous malformations (AVMs) of the brai...
# 2877521    Analyzing an input-output relationship from sa...
# 2878408    Breast cancer is among the most common cancers...
# 2879698    In oxygen involving metabolisms like photoresp...
# 2879848    The vestibular system detects angular and line...
# 213466066  Aviation meteorology is the most important asp...
# 116985999  Observations of extragalactic background light...
# 116987163  On the first day of our symposium. the contrib...
# 116988830  In [1] , the Lazer-McKenna suspension bridge m...
# 118860172  In the last decade, spectropolarimetric survey...
# 118861869  A tidal disruption event (TDE) occurs when a s...
# 118863510  Over the last twenty years, research about com...
# 118863857  Cosmic rays (CRs, hereafter) are high-energy p...
# 118864086  At exceptional points (EPs), at least two eige...
# 118864492  Runaway massive stars are stars with high spat...
# 118864667  Complete samples of circumstellar disks in sta...
# 118866026  In July 2012, the Higgs boson was discovered a...
# 84882469   Anatolia is the main centre of Salvia species ...
#
#                                              full_text_pairs
# paper_id
# 94551546   {'4683185': 'The application of traditional vi...
# 18981358   {'18136308': 'There is a clear difference betw...
# 18982127   {'6739367': 'For a more extensive study on thi...
# 18982460   {'34028337': 'Benign prostatic hyperplasia (BP...
# 18982504   {'5786126': 'The advantages gained by vertical...
# 18982781   {'22689447': 'Administration of exogenous DHT ...
# 18983391   {'5173944': 'We study the routing and load bal...
# 18985891   {'22675707': 'Our study provides a baseline es...
# 18986705                                                  {}
# 18986901   {'118117994': 'The formalism for the dho turns...
# 18987532   {'42507328': 'Because the number of infused CD...
# 18987535   {'90991747': 'As dengue cases are expanding gl...
# 18987990                                                  {}
# 18989350   {'19058822': 'Genetic linkage maps are essenti...
# 199662866  {'24027525': 'There is thus an incongruity tha...
# 199665542  {'14984086': 'Possible references on the physi...
# 199665735  {'35126346': 'Isolation and identifi cation of...
# 199668887  {'16861557': 'Federated learning produces pers...
# 199668943  {'11833172': 'Unfortunately, these datasets ar...
# 2870075    {'30603813': 'Moreover, the path length of sou...
# 2870145    {'75728969': 'The associated Mediators of Infl...
# 2870542    {'79010550': 'As the patient safety agenda has...
# 2872613    {'6544283': 'Incidence of falls escalates with...
# 2873021    {'809177': 'In the scientific community there ...
# 2874360    {'5189123': 'Techniques related to endoscopic ...
# 2874531    {'2885558': 'Before the educational reform was...
# 2875387    {'121586358': 'Pyramid data structures, in par...
# 2877021    {'10514660': 'SR refers to the fact that at an...
# 2877038    {'9556839': 'In particular, Swift protocol sup...
# 2877272    {'33391199': 'This transition has enabled rapi...
# 2877521    {'7813665': 'LSCDE: Least-squares conditional ...
# 2878408    {'3000481': 'Diabetes is also associated with ...
# 2879698    {'17229119': 'Microalgae have to counteract th...
# 2879848    {'15313209': 'Clinical evidence suggests that ...
# 213466066  {'124346885': 'Weather forecast verification p...
# 116985999                                                 {}
# 116987163                                                 {}
# 116988830  {'28937824': 'Such case is called as semiposit...
# 118860172                                                 {}
# 118861869                                                 {}
# 118863510  {'57479176': 'One example of such a parallel i...
# 118863857                                                 {}
# 118864086  {'119167805': 'At exceptional points (EPs), at...
# 118864492                                                 {}
# 118864667                                                 {}
# 118866026                                                 {}
# 84882469   {'40506974': 'In addition to these features, i...
