# %%
import os
import pandas as pd
import numpy as np

from collections import Counter
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Input
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras import metrics
from keras.optimizers import Adam, SGD

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_pickle('../dataset/SS/clean/withlabel_SPECTER.pkl')
df.head()
# Out:
#                                                        title  \
# paper_id
# 859921     Summarizing Reviews with Variable-length Synta...
# 129124     Can Document Selection Help Semi-supervised Le...
# 1345235    Optimizing Sparse Matrix–Vector Product Comput...
# 2624639    Enhanced Chosen-Ciphertext Security and Applic...
# 146120525  ARSM: Augment-REINFORCE-Swap-Merge Estimator f...
#
#                                                     abstract  \
# paper_id
# 859921     Abstract. We present a novel summarization fra...
# 129124     Annotating training data for event extraction ...
# 1345235    Large-scale scientific applications frequently...
# 2624639    We introduce and study a new notion of enhance...
# 146120525  To address the challenge of backpropagating th...
#
#                                             relatedwork_text  \
# paper_id
# 859921     We first look at how text excerpts are extract...
# 129124     Self-training has been applied to several natu...
# 1345235    A variety of different data and computation re...
# 2624639    ECCA is similar in spirit to coin-revealing se...
# 146120525  For optimizing (1) for categorical z, the diff...
#
#                                                    main_text  \
# paper_id
# 859921     Abstract. We present a novel summarization fra...
# 129124     Annotating training data for event extraction ...
# 1345235    Large-scale scientific applications frequently...
# 2624639    We introduce and study a new notion of enhance...
# 146120525  To address the challenge of backpropagating th...
#
#                                                 rw_citations  \
# paper_id
# 859921          [5965756, 1599046, 3177797, 444032, 6884774]
# 129124     [1398439, 7419156, 11187670, 8336242, 15894892...
# 1345235    [1794629, 9580801, 120335238, 15090599, 208582...
# 2624639           [41204165, 19655, 235427, 226828, 3148885]
# 146120525  [3535369, 5859948, 1758804, 10756562, 19115634...
#
#                                               full_citations  \
# paper_id
# 859921     [1599046, 11055565, 16393334, 2481864, 5965756...
# 129124     [1398439, 7419156, 7579604, 11187670, 8336242,...
# 1345235    [1794629, 9580801, 120335238, 15090599, 208582...
# 2624639    [443317, 41204165, 7113862, 10098664, 226828, ...
# 146120525  [121929631, 4043645, 5859948, 7195970, 1075656...
#
#                                           SPECTER_embeddings label
# paper_id
# 859921     [-0.7218136, 0.99761677, -0.27647057, 0.235195...     2
# 129124     [-0.46521527, 0.17172785, 0.27331015, 0.088347...     2
# 1345235    [-0.16910633, 0.8334114, 0.039647657, -0.09229...     3
# 2624639    [0.12169194, 0.04154425, 0.2388953, 0.03814739...     1
# 146120525  [-0.8591176, 0.8032798, -0.012844058, 0.021643...     2

# %%
Counter(df['label'])
# Out:
# Counter({2: 4160, 3: 4914, 1: 4047, 0: 7807, 4: 6489})

# %%
df_cluster = df.loc[df.label == 4]
df_cluster.head()
# Out:
#                                                        title  \
# paper_id
# 16102392   Understanding Diversity – The Impact of Person...
# 7104902    Using Linked Data Traversal to Label Academic ...
# 11131121   sTeam - Designing an integrative infrastructur...
# 210157074  Choosing the Sample with Lowest Loss makes SGD...
# 208822039  A Study on Trend Analysis of Applicants Based ...
#
#                                                     abstract  \
# paper_id
# 16102392   Technology is becoming increasingly automated,...
# 7104902    In this paper we exploit knowledge from Linked...
# 11131121   Learning is a socially embedded design process...
# 210157074  The presence of outliers can potentially signi...
# 208822039  In recent times, with the development of scien...
#
#                                             relatedwork_text  \
# paper_id
# 16102392   The effect of personality on technology accept...
# 7104902    Our work finds its place at the intersection b...
# 11131121   A comprehensive treatment of the sTeam approac...
# 210157074  The related work can be divided into the follo...
# 208822039  Data mining techniques have seen a tremendous ...
#
#                                                    main_text  \
# paper_id
# 16102392   Technology is becoming increasingly automated,...
# 7104902    In this paper we exploit knowledge from Linked...
# 11131121   Learning is a socially embedded design process...
# 210157074  The presence of outliers can potentially signi...
# 208822039  In recent times, with the development of scien...
#
#                                                 rw_citations  \
# paper_id
# 16102392   [6742907, 205482675, 206613343, 10858366, 1458...
# 7104902      [6785866, 1034563, 16257494, 3821256, 13998523]
# 11131121    [13472373, 14163292, 5900571, 8901760, 15134769]
# 210157074     [51876228, 3511978, 29767720, 1977996, 873046]
# 208822039  [67929270, 115288648, 29867338, 64652083, 1995...
#
#                                               full_citations  \
# paper_id
# 16102392   [6742907, 205482675, 220766, 206613343, 184904...
# 7104902    [6785866, 1034563, 3348552, 40552078, 16257494...
# 11131121   [13472373, 151412990, 14163292, 11153819, 1088...
# 210157074  [3663876, 13199836, 1903919, 1977996, 1831685,...
# 208822039  [67929270, 115288648, 29867338, 116477453, 646...
#
#                                           SPECTER_embeddings label
# paper_id
# 16102392   [-0.4633501, 1.1482458, 0.57284164, -0.1838153...     4
# 7104902    [-1.0942944, 0.7161176, -0.29811218, -0.554687...     4
# 11131121   [-0.57170343, 0.17781031, 0.79073054, -0.55972...     4
# 210157074  [0.018174438, 0.65806544, -0.35516965, -0.4106...     4
# 208822039  [-0.9480523, 0.74624664, -0.69631267, -0.53817...     4

# %%
# Multi hot encoding for related works citations
mlb = MultiLabelBinarizer(sparse_output=True)

Y = pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(df_cluster['rw_citations']),
                index=df_cluster.index,
                columns=mlb.classes_)
Y.columns = Y.columns.astype(str)

# %%
Y.sum().value_counts()[0:20]
# Out:
# 1     32528
# 2      4542
# 3      1298
# 4       505
# 5       243
# 6       140
# 7        88
# 8        57
# 9        46
# 10       20
# 11       16
# 12       10
# 13        9
# 14        6
# 15        3
# 16        3
# 29        2
# 35        2
# 30        2
# 18        2
# dtype: int64

# %%
Y.sum().value_counts()[2:].sum()
# Out:
# 2457

# %%
#Filter out papers that are not cited at least a few times
Y = Y[Y.columns[Y.sum() > 2]]
Y
# Out:
#            10004443  10019293  1002166  10025642  1002614  1004256  10061486  \
# paper_id
# 16102392          0         0        0         0        0        0         0
# 7104902           0         0        0         0        0        0         0
# 11131121          0         0        0         0        0        0         0
# 210157074         0         0        0         0        0        0         0
# 208822039         0         0        0         0        0        0         0
# ...             ...       ...      ...       ...      ...      ...       ...
# 427597            0         0        0         0        0        0         0
# 998422            0         0        0         0        0        0         0
# 353336            0         0        0         0        0        0         0
# 5778372           0         0        0         0        0        0         0
# 2118918           0         0        0         0        0        0         0
#
#            10071285  10082102  10094229  ...  9922703  9924032  9939431  \
# paper_id                                 ...
# 16102392          0         0         0  ...        0        0        0
# 7104902           0         0         0  ...        0        0        0
# 11131121          0         0         0  ...        0        0        0
# 210157074         0         0         0  ...        0        0        0
# 208822039         0         0         0  ...        0        0        0
# ...             ...       ...       ...  ...      ...      ...      ...
# 427597            0         0         0  ...        0        0        0
# 998422            0         0         0  ...        0        0        0
# 353336            0         0         0  ...        0        0        0
# 5778372           0         0         0  ...        0        0        0
# 2118918           0         0         0  ...        0        0        0
#
#            9942426  9959495  9973484  9989830  999108  9995163  999548
# paper_id
# 16102392         0        0        0        0       0        0       0
# 7104902          0        0        0        0       0        0       0
# 11131121         0        0        0        0       0        0       0
# 210157074        0        0        0        0       0        0       0
# 208822039        0        0        0        0       0        0       0
# ...            ...      ...      ...      ...     ...      ...     ...
# 427597           0        0        0        0       0        0       0
# 998422           0        0        0        0       0        0       0
# 353336           0        0        0        0       0        0       0
# 5778372          0        0        0        0       0        0       0
# 2118918          0        0        0        0       0        0       0
#
# [6489 rows x 2457 columns]

# %%
#Remove papers with less than 1 cited papers after filter
Y = Y.loc[Y.sum(axis=1) > 1]
Y.shape
# Out:
# (2470, 2457)

# %%
X = pd.DataFrame(df_cluster['SPECTER_embeddings'].to_list(), index= df_cluster.index)

#Filter out the same rows for predictive variables as well
X = X[X.index.isin(Y.index)]
X.head()
# Out:
#                 0         1         2         3         4         5    \
# paper_id
# 210157074  0.018174  0.658065 -0.355170 -0.410615 -0.448705  0.121680
# 5323444    0.131840  0.523287  0.293483 -0.310287  0.084417 -0.263740
# 5059562   -0.772302  0.495468 -0.640621  0.039978  0.146960 -0.196236
# 160017440 -0.318960 -0.146229 -0.228779 -0.766527 -0.590969  0.508096
# 12753527  -0.375375  0.373230  0.079491 -0.523268 -0.293293 -0.263985
#
#                 6         7         8         9    ...       758       759  \
# paper_id                                           ...
# 210157074  1.032814  0.435326  0.492442  0.260239  ... -0.267624 -0.338045
# 5323444    0.725161  0.160016  0.552869  0.664954  ...  0.061488 -1.294262
# 5059562    0.112502  0.707713  0.299266  1.280529  ... -0.401255 -0.628942
# 160017440  1.166123  0.268243  0.940369  0.278230  ...  0.220822 -0.375817
# 12753527   1.022384  0.212618  0.723335  0.440487  ...  0.809094 -0.560377
#
#                 760       761       762       763       764       765  \
# paper_id
# 210157074  0.496968  0.344923 -0.082258  0.308193  0.694703  0.074032
# 5323444    0.000978  0.289469  0.691297  0.242660  0.165879  0.580002
# 5059562    0.707693  0.278066  0.760401 -0.008689  0.349209  0.386530
# 160017440  0.465768  0.359907 -0.375501 -0.015964 -0.306176 -0.100403
# 12753527  -0.245490  0.422324 -0.117240 -0.653949 -0.392122 -0.141519
#
#                 766       767
# paper_id
# 210157074  0.115646  0.433317
# 5323444    0.650422  0.118085
# 5059562    0.763354  0.168942
# 160017440 -0.442102  0.580200
# 12753527  -0.309668  0.550817
#
# [5 rows x 768 columns]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (2470, 768)
# (2470, 2457)

# %%
#Create train set and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

# %%
#Create train set and validation set
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=1)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (1889, 768)
# (1889, 2457)

# %% [markdown]
# # NN Model

# %%
batch_size = 256
num_classes = Y_train.shape[1]
epochs = 100

# %%
Y_test.shape
# Out:
# (371, 2457)

# %%
embedding_dim = X_train.shape[1]

model = Sequential()
model.add(Dense(256, input_dim=embedding_dim, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               196864
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2457)              631449
# =================================================================
# Total params: 828,313
# Trainable params: 828,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=10)
history = model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[es],
                    validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0124 - accuracy: 0.0000e+00 - val_loss: 0.0131 - val_accuracy: 0.0048
# Epoch 2/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0123 - accuracy: 0.0016 - val_loss: 0.0131 - val_accuracy: 0.0048
# Epoch 3/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0121 - accuracy: 0.0048 - val_loss: 0.0130 - val_accuracy: 0.0048
# Epoch 4/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0120 - accuracy: 0.0042 - val_loss: 0.0130 - val_accuracy: 0.0048
# Epoch 5/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0117 - accuracy: 0.0037 - val_loss: 0.0130 - val_accuracy: 0.0048
# Epoch 6/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0115 - accuracy: 0.0074 - val_loss: 0.0129 - val_accuracy: 0.0095
# Epoch 7/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0112 - accuracy: 0.0111 - val_loss: 0.0127 - val_accuracy: 0.0048
# Epoch 8/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0109 - accuracy: 0.0191 - val_loss: 0.0126 - val_accuracy: 0.0190
# Epoch 9/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0105 - accuracy: 0.0206 - val_loss: 0.0124 - val_accuracy: 0.0143
# Epoch 10/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0101 - accuracy: 0.0291 - val_loss: 0.0122 - val_accuracy: 0.0190
# Epoch 11/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0097 - accuracy: 0.0312 - val_loss: 0.0120 - val_accuracy: 0.0190
# Epoch 12/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0092 - accuracy: 0.0471 - val_loss: 0.0118 - val_accuracy: 0.0190
# Epoch 13/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0089 - accuracy: 0.0577 - val_loss: 0.0115 - val_accuracy: 0.0190
# Epoch 14/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0085 - accuracy: 0.0651 - val_loss: 0.0113 - val_accuracy: 0.0190
# Epoch 15/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0081 - accuracy: 0.0699 - val_loss: 0.0111 - val_accuracy: 0.0238
# Epoch 16/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0078 - accuracy: 0.0873 - val_loss: 0.0110 - val_accuracy: 0.0095
# Epoch 17/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0075 - accuracy: 0.1075 - val_loss: 0.0108 - val_accuracy: 0.0238
# Epoch 18/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0072 - accuracy: 0.0926 - val_loss: 0.0107 - val_accuracy: 0.0476
# Epoch 19/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0069 - accuracy: 0.1143 - val_loss: 0.0107 - val_accuracy: 0.0333
# Epoch 20/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0067 - accuracy: 0.1355 - val_loss: 0.0106 - val_accuracy: 0.0238
# Epoch 21/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0064 - accuracy: 0.1424 - val_loss: 0.0106 - val_accuracy: 0.0190
# Epoch 22/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0062 - accuracy: 0.1519 - val_loss: 0.0106 - val_accuracy: 0.0095
# Epoch 23/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0061 - accuracy: 0.1567 - val_loss: 0.0106 - val_accuracy: 0.0333
# Epoch 24/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0058 - accuracy: 0.1879 - val_loss: 0.0106 - val_accuracy: 0.0476
# Epoch 25/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0057 - accuracy: 0.1911 - val_loss: 0.0106 - val_accuracy: 0.0381
# Epoch 26/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0055 - accuracy: 0.2038 - val_loss: 0.0106 - val_accuracy: 0.0286
# Epoch 27/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0054 - accuracy: 0.2118 - val_loss: 0.0106 - val_accuracy: 0.0286
# Epoch 28/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0053 - accuracy: 0.2155 - val_loss: 0.0107 - val_accuracy: 0.0286
# Epoch 29/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0052 - accuracy: 0.2213 - val_loss: 0.0107 - val_accuracy: 0.0286
# Epoch 30/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0051 - accuracy: 0.2308 - val_loss: 0.0107 - val_accuracy: 0.0476
# Epoch 31/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0049 - accuracy: 0.2472 - val_loss: 0.0108 - val_accuracy: 0.0429
# Epoch 32/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0048 - accuracy: 0.2435 - val_loss: 0.0109 - val_accuracy: 0.0476

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

fig, ax = plt.subplots(1,1, figsize=(10,6))

ax.plot(epochs, acc, 'r', label='Training acc')
ax.plot(epochs, val_acc, 'b', label='Validation acc')
ax.set_title('Accuracy', fontsize=18)
ax.set_xlabel(r'Epochs', fontsize=18)
ax.set_ylabel(r'Accuracy', fontsize=18)
ax.tick_params(labelsize=18)
ax.legend(fontsize=20)

plt.show()

figL, axL = plt.subplots(1,1, figsize=(10,6))

axL.plot(epochs, loss, 'r', label='Training loss')
axL.plot(epochs, val_loss, 'b', label='Validation loss')
axL.set_title('Loss', fontsize=18)
axL.set_xlabel(r'Epochs', fontsize=18)
axL.set_ylabel(r'Loss', fontsize=18)
axL.tick_params(labelsize=18)
axL.legend(fontsize=20)

plt.show()

# %% [markdown]
# # Model Evaluation with Information Retrieval Metrics

# %%
from src.metric_utils import MAP_score
from src.metric_utils import Recall_score

# %%
#Get probabilities for each citation
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# %%
train_MAP, test_MAP = MAP_score(Y_train, Y_test, train_predictions, test_predictions, top_k=5)

print("Training MAP Score: ", train_MAP)
print("Test MAP Score: ", test_MAP)
# Out:
# Training MAP Score:  0.5232871595788483
# Test MAP Score:  0.08283692722371967

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=10)

print("Training Recall Score @10:", train_recall)
print("Test Recall Score @10:", test_recall)
# Out:
# Training Recall Score @10: 0.9576134027326323
# Test Recall Score @10: 0.21685512222217468

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=20)

print("Training Recall Score @20:", train_recall)
print("Test Recall Score @20:", test_recall)
# Out:
# Training Recall Score @20: 0.9870827718265097
# Test Recall Score @20: 0.3160773879855852

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=50)

print("Training Recall Score @50:", train_recall)
print("Test Recall Score @50:", test_recall)
# Out:
# Training Recall Score @50: 0.9974825784241793
# Test Recall Score @50: 0.46548101846183343

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=100)

print("Training Recall Score @100:", train_recall)
print("Test Recall Score @100:", test_recall)
# Out:
# Training Recall Score @100: 0.999647079583554
# Test Recall Score @100: 0.5815975833971712
