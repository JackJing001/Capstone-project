# %%
import os
import pandas as pd
import numpy as np

from collections import Counter
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Input
from sklearn.model_selection import train_test_split
from keras.utils import np_utils

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_pickle('../dataset/SS/clean/withlabel.pkl')
df.head()
# Out:
#                                                        title  \
# paper_id
# 859921     Summarizing Reviews with Variable-length Synta...
# 129124     Can Document Selection Help Semi-supervised Le...
# 1345235    Optimizing Sparse Matrix–Vector Product Comput...
# 2624639    Enhanced Chosen-Ciphertext Security and Applic...
# 146120525  ARSM: Augment-REINFORCE-Swap-Merge Estimator f...
#
#                                                     abstract  \
# paper_id
# 859921     Abstract. We present a novel summarization fra...
# 129124     Annotating training data for event extraction ...
# 1345235    Large-scale scientific applications frequently...
# 2624639    We introduce and study a new notion of enhance...
# 146120525  To address the challenge of backpropagating th...
#
#                                             relatedwork_text  \
# paper_id
# 859921     We first look at how text excerpts are extract...
# 129124     Self-training has been applied to several natu...
# 1345235    A variety of different data and computation re...
# 2624639    ECCA is similar in spirit to coin-revealing se...
# 146120525  For optimizing (1) for categorical z, the diff...
#
#                                                    main_text  \
# paper_id
# 859921     Abstract. We present a novel summarization fra...
# 129124     Annotating training data for event extraction ...
# 1345235    Large-scale scientific applications frequently...
# 2624639    We introduce and study a new notion of enhance...
# 146120525  To address the challenge of backpropagating th...
#
#                                                 rw_citations  \
# paper_id
# 859921          [5965756, 1599046, 3177797, 444032, 6884774]
# 129124     [1398439, 7419156, 11187670, 8336242, 15894892...
# 1345235    [1794629, 9580801, 120335238, 15090599, 208582...
# 2624639           [41204165, 19655, 235427, 226828, 3148885]
# 146120525  [3535369, 5859948, 1758804, 10756562, 19115634...
#
#                                               full_citations  \
# paper_id
# 859921     [1599046, 11055565, 16393334, 2481864, 5965756...
# 129124     [1398439, 7419156, 7579604, 11187670, 8336242,...
# 1345235    [1794629, 9580801, 120335238, 15090599, 208582...
# 2624639    [443317, 41204165, 7113862, 10098664, 226828, ...
# 146120525  [121929631, 4043645, 5859948, 7195970, 1075656...
#
#                                              BERT_embeddings label
# paper_id
# 859921     [-0.5292661, 0.96171594, 0.7239495, 0.09007428...     1
# 129124     [-0.7070601, 0.5793047, 0.30019873, 0.451895, ...     1
# 1345235    [-0.72422814, 0.38941112, 0.50098884, -0.02656...     1
# 2624639    [-0.59993136, 0.84347814, 0.1958661, 0.2972666...     2
# 146120525  [-0.78408253, 0.022130227, 0.31313884, 0.46616...     0

# %%
Counter(df['label'])
# Out:
# Counter({1: 4583, 2: 5688, 0: 7025, 4: 4029, 3: 6092})

# %%
df_cluster = df.loc[df.label == 0]
df_cluster.head()
# Out:
#                                                        title  \
# paper_id
# 146120525  ARSM: Augment-REINFORCE-Swap-Merge Estimator f...
# 42490916   Person Re-Identification as Image Retrieval Us...
# 54439672   Revisiting the Softmax Bellman Operator: Theor...
# 9446888    Coupled Sequence Labeling on Heterogeneous Ann...
# 6961896    TAG, Dynamic Programming, and the Perceptron f...
#
#                                                     abstract  \
# paper_id
# 146120525  To address the challenge of backpropagating th...
# 42490916   Person re-identification is a challenging prob...
# 54439672   The softmax function has been primarily employ...
# 9446888    In order to effectively utilize multiple datas...
# 6961896    We describe a parsing approach that makes use ...
#
#                                             relatedwork_text  \
# paper_id
# 146120525  For optimizing (1) for categorical z, the diff...
# 42490916   Person Re-identification A lot of methods have...
# 54439672   Among variants of the DQN in Mnih et al. (2015...
# 9446888    This work is partially inspired by Qiu et al. ...
# 6961896    Previous work has made use of various restrict...
#
#                                                    main_text  \
# paper_id
# 146120525  To address the challenge of backpropagating th...
# 42490916   Person re-identification is a challenging prob...
# 54439672   The softmax function has been primarily employ...
# 9446888    In order to effectively utilize multiple datas...
# 6961896    We describe a parsing approach that makes use ...
#
#                                                 rw_citations  \
# paper_id
# 146120525  [3535369, 5859948, 1758804, 10756562, 19115634...
# 42490916   [11864530, 3961724, 16510219, 6485959, 7973738...
# 54439672   [5389801, 205242740, 19135734, 13022595, 68753...
# 9446888    [7527306, 917949, 5517166, 2037646, 14014145, ...
# 6961896    [803811, 405878, 5897173, 11599080, 8313435, 1...
#
#                                               full_citations  \
# paper_id
# 146120525  [121929631, 4043645, 5859948, 7195970, 1075656...
# 42490916   [14678946, 425268, 11864530, 14457153, 9107599...
# 54439672   [14530441, 13022595, 10713737, 5389801, 198118...
# 9446888    [2082658, 7527306, 125278, 5517166, 2037646, 1...
# 6961896    [13163488, 405878, 1131864, 8313435, 14759233,...
#
#                                              BERT_embeddings label
# paper_id
# 146120525  [-0.78408253, 0.022130227, 0.31313884, 0.46616...     0
# 42490916   [-0.4096449, 0.74160963, 0.739921, 0.48732576,...     0
# 54439672   [-0.85142934, -0.021963624, 0.5845745, 0.29520...     0
# 9446888    [-0.6339155, 0.629671, -0.02281475, 0.41130206...     0
# 6961896    [-1.1306897, 0.6080086, 0.7361808, 0.45112845,...     0

# %%
# Multi hot encoding for related works citations
mlb = MultiLabelBinarizer(sparse_output=True)

Y = pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(df_cluster['rw_citations']),
                index=df_cluster.index,
                columns=mlb.classes_)
Y.columns = Y.columns.astype(str)

# %%
Y.sum().value_counts()[0:20]
# Out:
# 1     31792
# 2      4853
# 3      1544
# 4       656
# 5       352
# 6       218
# 7       129
# 8        80
# 9        77
# 10       55
# 11       43
# 12       27
# 14       26
# 13       19
# 18       14
# 17       13
# 16       13
# 15        8
# 21        7
# 20        7
# dtype: int64

# %%
Y.sum().value_counts()[3:].sum()
# Out:
# 1800

# %%
#Filter out papers that are not cited at least a few times
Y = Y[Y.columns[Y.sum() > 3]]
Y
# Out:
#            10004443  10004927  1003795  10048432  10054272  10070153  \
# paper_id
# 146120525         0         0        0         0         0         0
# 42490916          0         0        0         0         0         0
# 54439672          0         0        0         0         0         0
# 9446888           0         0        0         0         0         0
# 6961896           0         0        0         0         0         0
# ...             ...       ...      ...       ...       ...       ...
# 9408833           0         0        0         0         0         0
# 199501884         0         0        0         0         0         0
# 7151908           0         0        0         0         0         0
# 3071736           0         0        0         0         0         0
# 16717950          0         0        0         0         0         0
#
#            10086161  1009127  10091362  10097073  ...  988348  9901844  \
# paper_id                                          ...
# 146120525         0        0         0         0  ...       0        0
# 42490916          0        0         0         0  ...       0        0
# 54439672          0        0         0         0  ...       0        0
# 9446888           0        0         0         0  ...       0        0
# 6961896           0        0         0         0  ...       0        0
# ...             ...      ...       ...       ...  ...     ...      ...
# 9408833           0        0         0         0  ...       0        0
# 199501884         0        0         0         0  ...       0        0
# 7151908           0        0         0         0  ...       0        0
# 3071736           0        0         0         0  ...       0        0
# 16717950          0        0         1         0  ...       0        0
#
#            990233  9926549  9933254  9936656  9944232  9957731  996788  \
# paper_id
# 146120525       0        0        0        0        0        0       0
# 42490916        0        0        0        0        0        0       0
# 54439672        0        0        0        0        0        0       0
# 9446888         0        0        0        0        0        0       0
# 6961896         0        0        0        0        0        0       0
# ...           ...      ...      ...      ...      ...      ...     ...
# 9408833         0        0        0        0        0        0       0
# 199501884       0        0        0        0        0        0       0
# 7151908         0        0        0        0        0        0       0
# 3071736         0        0        0        0        0        0       0
# 16717950        0        0        0        0        0        0       0
#
#            9971732
# paper_id
# 146120525        0
# 42490916         0
# 54439672         0
# 9446888          0
# 6961896          0
# ...            ...
# 9408833          0
# 199501884        0
# 7151908          0
# 3071736          0
# 16717950         0
#
# [7025 rows x 1800 columns]

# %%
#Remove papers with less than 1 cited papers after filter
Y = Y.loc[Y.sum(axis=1) > 1]
Y.shape
# Out:
# (2646, 1800)

# %%
X = pd.DataFrame(df_cluster['BERT_embeddings'].to_list(), index= df_cluster.index)

#Filter out the same rows for predictive variables as well
X = X[X.index.isin(Y.index)]
X.head()
# Out:
#                 0         1         2         3         4         5    \
# paper_id
# 146120525 -0.784083  0.022130  0.313139  0.466162  0.375948 -0.084934
# 42490916  -0.409645  0.741610  0.739921  0.487326  0.525650  0.112215
# 54439672  -0.851429 -0.021964  0.584575  0.295210  0.242013 -0.835870
# 6961896   -1.130690  0.608009  0.736181  0.451128  0.261825 -0.831881
# 210157074 -1.204505  0.535836  0.211619  0.190260  0.192084 -0.245387
#
#                 6         7         8         9    ...       758       759  \
# paper_id                                           ...
# 146120525  0.115169 -0.373222  0.548126 -0.022766  ...  0.018562 -0.220173
# 42490916   0.854650 -0.528566  0.495862 -0.636842  ... -0.265085 -0.369111
# 54439672  -0.019311 -0.516967  0.694569 -0.177241  ... -0.206474 -0.363318
# 6961896    0.455380 -0.129807  0.647254 -0.174164  ... -0.323724 -0.222024
# 210157074  0.631579 -0.433965  0.350419 -0.128668  ... -0.372202  0.315975
#
#                 760       761       762       763       764       765  \
# paper_id
# 146120525 -0.627976 -0.927026 -0.636514 -0.534005 -0.339940 -0.041008
# 42490916  -1.011387 -1.457536 -0.378962 -0.121988 -0.359988 -0.063296
# 54439672  -1.020956 -0.926032  0.223877 -0.339086 -0.333416 -0.005439
# 6961896   -0.972184 -1.239182 -0.663214 -0.424737 -0.128913 -0.439037
# 210157074 -1.002957 -1.266373 -0.593963 -0.250572 -0.272906 -0.430407
#
#                 766       767
# paper_id
# 146120525 -0.484693  0.637083
# 42490916  -0.911964  0.662830
# 54439672  -0.606132  0.653953
# 6961896   -0.783366  0.541020
# 210157074 -0.757850  0.972793
#
# [5 rows x 768 columns]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (2646, 768)
# (2646, 1800)

# %%
#Create train set and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

# %%
#Create train set and validation set
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=1)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (2024, 768)
# (2024, 1800)

# %% [markdown]
# # NN Model

# %%
batch_size = 256
num_classes = Y_train.shape[1]
epochs = 100

# %%
Y_test.shape
# Out:
# (397, 1800)

# %%
embedding_dim = X_train.shape[1]

model = Sequential()
model.add(Dense(768, input_dim=embedding_dim, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2000, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(4000, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 768)               590592
# _________________________________________________________________
# dropout (Dropout)            (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2000)              1538000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4000)              8004000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1800)              7201800
# =================================================================
# Total params: 17,334,392
# Trainable params: 17,334,392
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=15)
history = model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[es],
                    validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0190 - accuracy: 0.0252 - val_loss: 0.0183 - val_accuracy: 0.0222
# Epoch 2/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0186 - accuracy: 0.0158 - val_loss: 0.0183 - val_accuracy: 0.0222
# Epoch 3/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0184 - accuracy: 0.0371 - val_loss: 0.0182 - val_accuracy: 0.0267
# Epoch 4/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0182 - accuracy: 0.0356 - val_loss: 0.0180 - val_accuracy: 0.0267
# Epoch 5/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0178 - accuracy: 0.0232 - val_loss: 0.0177 - val_accuracy: 0.0222
# Epoch 6/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0172 - accuracy: 0.0326 - val_loss: 0.0175 - val_accuracy: 0.0044
# Epoch 7/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0165 - accuracy: 0.0301 - val_loss: 0.0171 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 8/8 [==============================] - 1s 114ms/step - loss: 0.0158 - accuracy: 0.0287 - val_loss: 0.0170 - val_accuracy: 0.0178
# Epoch 9/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0152 - accuracy: 0.0380 - val_loss: 0.0169 - val_accuracy: 0.0044
# Epoch 10/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0143 - accuracy: 0.0450 - val_loss: 0.0169 - val_accuracy: 0.0044
# Epoch 11/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0135 - accuracy: 0.0539 - val_loss: 0.0171 - val_accuracy: 0.0133
# Epoch 12/100
# 8/8 [==============================] - 1s 120ms/step - loss: 0.0128 - accuracy: 0.0702 - val_loss: 0.0171 - val_accuracy: 0.0089
# Epoch 13/100
# 8/8 [==============================] - 1s 114ms/step - loss: 0.0120 - accuracy: 0.0963 - val_loss: 0.0178 - val_accuracy: 0.0178
# Epoch 14/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0113 - accuracy: 0.1057 - val_loss: 0.0179 - val_accuracy: 0.0222
# Epoch 15/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0106 - accuracy: 0.1324 - val_loss: 0.0182 - val_accuracy: 0.0267
# Epoch 16/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0101 - accuracy: 0.1556 - val_loss: 0.0187 - val_accuracy: 0.0089
# Epoch 17/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0093 - accuracy: 0.1858 - val_loss: 0.0191 - val_accuracy: 0.0178
# Epoch 18/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0087 - accuracy: 0.2278 - val_loss: 0.0195 - val_accuracy: 0.0089
# Epoch 19/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0082 - accuracy: 0.2307 - val_loss: 0.0198 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0079 - accuracy: 0.2614 - val_loss: 0.0201 - val_accuracy: 0.0178
# Epoch 21/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0075 - accuracy: 0.2772 - val_loss: 0.0201 - val_accuracy: 0.0089
# Epoch 22/100
# 8/8 [==============================] - 1s 113ms/step - loss: 0.0072 - accuracy: 0.2856 - val_loss: 0.0201 - val_accuracy: 0.0222
# Epoch 23/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0070 - accuracy: 0.2638 - val_loss: 0.0203 - val_accuracy: 0.0133
# Epoch 24/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0068 - accuracy: 0.2900 - val_loss: 0.0203 - val_accuracy: 0.0178

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

fig, ax = plt.subplots(1,1, figsize=(10,6))

ax.plot(epochs, acc, 'r', label='Training acc')
ax.plot(epochs, val_acc, 'b', label='Validation acc')
ax.set_title('Accuracy', fontsize=18)
ax.set_xlabel(r'Epochs', fontsize=18)
ax.set_ylabel(r'Accuracy', fontsize=18)
ax.tick_params(labelsize=18)
ax.legend(fontsize=20)

plt.show()

figL, axL = plt.subplots(1,1, figsize=(10,6))

axL.plot(epochs, loss, 'r', label='Training loss')
axL.plot(epochs, val_loss, 'b', label='Validation loss')
axL.set_title('Loss', fontsize=18)
axL.set_xlabel(r'Epochs', fontsize=18)
axL.set_ylabel(r'Loss', fontsize=18)
axL.tick_params(labelsize=18)
axL.legend(fontsize=20)

plt.show()

# %% [markdown]
# # Model Evaluation with Information Retrieval Metrics

# %%
from src.metric_utils import MAP_score
from src.metric_utils import Recall_score

# %%
#Get probabilities for each citation
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# %%
train_MAP, test_MAP = MAP_score(Y_train, Y_test, train_predictions, test_predictions, top_k=5)

print("Training MAP Score: ", train_MAP)
print("Test MAP Score: ", test_MAP)
# Out:
# Training MAP Score:  0.6164087889767237
# Test MAP Score:  0.04369577385950182

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=10)

print("Training Recall Score @10:", train_recall)
print("Test Recall Score @10:", test_recall)
# Out:
# Training Recall Score @10: 0.9709860927799662
# Test Recall Score @10: 0.1097690591897141

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=20)

print("Training Recall Score @20:", train_recall)
print("Test Recall Score @20:", test_recall)
# Out:
# Training Recall Score @20: 0.9940458687436659
# Test Recall Score @20: 0.16864140580283712

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=50)

print("Training Recall Score @50:", train_recall)
print("Test Recall Score @50:", test_recall)
# Out:
# Training Recall Score @50: 0.999177147710547
# Test Recall Score @50: 0.28640529058479863

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=100)

print("Training Recall Score @100:", train_recall)
print("Test Recall Score @100:", test_recall)
# Out:
# Training Recall Score @100: 0.9995504114334779
# Test Recall Score @100: 0.40296955667492046
