# %%
import os
import pandas as pd
import numpy as np

from collections import Counter
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Input
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras import metrics
from keras.optimizers import Adam, SGD

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_pickle('../dataset/SS/clean/withlabel_SPECTER.pkl')
df.head()
# Out:
#                                                        title  \
# paper_id
# 859921     Summarizing Reviews with Variable-length Synta...
# 129124     Can Document Selection Help Semi-supervised Le...
# 1345235    Optimizing Sparse Matrix–Vector Product Comput...
# 2624639    Enhanced Chosen-Ciphertext Security and Applic...
# 146120525  ARSM: Augment-REINFORCE-Swap-Merge Estimator f...
#
#                                                     abstract  \
# paper_id
# 859921     Abstract. We present a novel summarization fra...
# 129124     Annotating training data for event extraction ...
# 1345235    Large-scale scientific applications frequently...
# 2624639    We introduce and study a new notion of enhance...
# 146120525  To address the challenge of backpropagating th...
#
#                                             relatedwork_text  \
# paper_id
# 859921     We first look at how text excerpts are extract...
# 129124     Self-training has been applied to several natu...
# 1345235    A variety of different data and computation re...
# 2624639    ECCA is similar in spirit to coin-revealing se...
# 146120525  For optimizing (1) for categorical z, the diff...
#
#                                                    main_text  \
# paper_id
# 859921     Abstract. We present a novel summarization fra...
# 129124     Annotating training data for event extraction ...
# 1345235    Large-scale scientific applications frequently...
# 2624639    We introduce and study a new notion of enhance...
# 146120525  To address the challenge of backpropagating th...
#
#                                                 rw_citations  \
# paper_id
# 859921          [5965756, 1599046, 3177797, 444032, 6884774]
# 129124     [1398439, 7419156, 11187670, 8336242, 15894892...
# 1345235    [1794629, 9580801, 120335238, 15090599, 208582...
# 2624639           [41204165, 19655, 235427, 226828, 3148885]
# 146120525  [3535369, 5859948, 1758804, 10756562, 19115634...
#
#                                               full_citations  \
# paper_id
# 859921     [1599046, 11055565, 16393334, 2481864, 5965756...
# 129124     [1398439, 7419156, 7579604, 11187670, 8336242,...
# 1345235    [1794629, 9580801, 120335238, 15090599, 208582...
# 2624639    [443317, 41204165, 7113862, 10098664, 226828, ...
# 146120525  [121929631, 4043645, 5859948, 7195970, 1075656...
#
#                                           SPECTER_embeddings label
# paper_id
# 859921     [-0.7218136, 0.99761677, -0.27647057, 0.235195...     2
# 129124     [-0.46521527, 0.17172785, 0.27331015, 0.088347...     2
# 1345235    [-0.16910633, 0.8334114, 0.039647657, -0.09229...     3
# 2624639    [0.12169194, 0.04154425, 0.2388953, 0.03814739...     1
# 146120525  [-0.8591176, 0.8032798, -0.012844058, 0.021643...     2

# %%
Counter(df['label'])
# Out:
# Counter({2: 4160, 3: 4914, 1: 4047, 0: 7807, 4: 6489})

# %%
df_cluster = df.loc[df.label == 1]
df_cluster.head()
# Out:
#                                                        title  \
# paper_id
# 2624639    Enhanced Chosen-Ciphertext Security and Applic...
# 213274317  Interference-aware lifetime maximization with ...
# 12372546        MOZART: Temporal Coordination of Measurement
# 2069424    Aggregated path authentication for efficient B...
# 33599910                 Trust Assessment Using Cloud Broker
#
#                                                     abstract  \
# paper_id
# 2624639    We introduce and study a new notion of enhance...
# 213274317  Radio Frequency based Wireless power transfer ...
# 12372546   In data center and ISP networks, many monitori...
# 2069424    The Border Gateway Protocol (BGP) controls int...
# 33599910   Abstract. Despite the advantages and rapid gro...
#
#                                             relatedwork_text  \
# paper_id
# 2624639    ECCA is similar in spirit to coin-revealing se...
# 213274317  Typically, an RF-WPT system consists of an ene...
# 12372546   There have been many traffic measurement solut...
# 2069424    The performance studies in [23, 25] offer deta...
# 33599910   Trust and reputation have been the focus of re...
#
#                                                    main_text  \
# paper_id
# 2624639    We introduce and study a new notion of enhance...
# 213274317  Radio Frequency based Wireless power transfer ...
# 12372546   In data center and ISP networks, many monitori...
# 2069424    The Border Gateway Protocol (BGP) controls int...
# 33599910   Abstract. Despite the advantages and rapid gro...
#
#                                                 rw_citations  \
# paper_id
# 2624639           [41204165, 19655, 235427, 226828, 3148885]
# 213274317  [51874284, 3641537, 8462603, 4167606, 63769966...
# 12372546   [589531, 13586413, 42667752, 14030881, 147977,...
# 2069424        [19143108, 59813392, 9902359, 48043, 3208171]
# 33599910    [9366645, 14307838, 43270081, 18726825, 1671373]
#
#                                               full_citations  \
# paper_id
# 2624639    [443317, 41204165, 7113862, 10098664, 226828, ...
# 213274317  [12945409, 414007, 3641537, 8462603, 51874284,...
# 12372546   [589531, 13586413, 3110172, 62729547, 653005, ...
# 2069424    [9902359, 5009545, 118150702, 34827987, 598133...
# 33599910   [9366645, 31496587, 14307838, 37497627, 432700...
#
#                                           SPECTER_embeddings label
# paper_id
# 2624639    [0.12169194, 0.04154425, 0.2388953, 0.03814739...     1
# 213274317  [-0.39416116, -1.0117339, 0.08702995, 0.457438...     1
# 12372546   [-0.12240554, -0.62082964, -0.48520437, -0.029...     1
# 2069424    [-0.3043693, 0.046541847, -0.5232613, 0.239121...     1
# 33599910   [0.31384265, 0.012929665, -1.0143601, 0.061250...     1

# %%
# Multi hot encoding for related works citations
mlb = MultiLabelBinarizer(sparse_output=True)

Y = pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(df_cluster['rw_citations']),
                index=df_cluster.index,
                columns=mlb.classes_)
Y.columns = Y.columns.astype(str)

# %%
Y.sum().value_counts()[0:20]
# Out:
# 1     24401
# 2      2235
# 3       511
# 4       191
# 5        63
# 6        29
# 7        18
# 9         6
# 8         6
# 10        3
# 11        3
# 12        3
# 16        2
# 13        2
# 20        2
# 14        1
# dtype: int64

# %%
Y.sum().value_counts()[2:].sum()
# Out:
# 840

# %%
#Filter out papers that are not cited at least a few times
Y = Y[Y.columns[Y.sum() > 2]]
Y
# Out:
#            10027410  10050921  1005154  10057122  10058214  10072679  1009825  \
# paper_id
# 2624639           0         0        0         0         0         0        0
# 213274317         0         0        0         0         0         0        0
# 12372546          0         0        0         0         0         0        0
# 2069424           0         0        0         0         0         0        0
# 33599910          0         0        0         0         0         0        0
# ...             ...       ...      ...       ...       ...       ...      ...
# 966101            0         0        0         0         0         0        0
# 206770693         0         0        0         0         0         0        0
# 6061992           0         0        0         0         0         0        0
# 34857887          0         0        0         0         0         0        0
# 3233483           0         0        0         0         0         0        0
#
#            10098344  1009884  10144321  ...  9648220  9656670  9692504  \
# paper_id                                ...
# 2624639           0        0         0  ...        0        0        0
# 213274317         0        0         0  ...        0        0        0
# 12372546          0        0         0  ...        0        0        0
# 2069424           0        0         0  ...        0        0        0
# 33599910          0        0         0  ...        0        0        0
# ...             ...      ...       ...  ...      ...      ...      ...
# 966101            0        0         0  ...        0        0        0
# 206770693         0        0         0  ...        0        0        0
# 6061992           0        0         0  ...        0        1        0
# 34857887          0        0         0  ...        0        0        0
# 3233483           0        0         0  ...        0        0        0
#
#            9835971  9847531  9851290  9858654  9864635  9924523  9953259
# paper_id
# 2624639          0        0        0        0        0        0        0
# 213274317        0        0        0        0        0        0        0
# 12372546         0        0        0        0        0        0        0
# 2069424          0        0        0        0        0        0        0
# 33599910         0        0        0        0        0        0        0
# ...            ...      ...      ...      ...      ...      ...      ...
# 966101           0        0        0        0        0        0        0
# 206770693        0        0        0        0        0        0        0
# 6061992          0        0        0        0        0        0        0
# 34857887         0        0        0        0        0        0        0
# 3233483          0        0        0        0        0        0        0
#
# [4047 rows x 840 columns]

# %%
#Remove papers with less than 1 cited papers after filter
Y = Y.loc[Y.sum(axis=1) > 1]
Y.shape
# Out:
# (804, 840)

# %%
X = pd.DataFrame(df_cluster['SPECTER_embeddings'].to_list(), index= df_cluster.index)

#Filter out the same rows for predictive variables as well
X = X[X.index.isin(Y.index)]
X.head()
# Out:
#                0         1         2         3         4         5    \
# paper_id
# 11214925  0.151118 -0.576353 -0.501017 -0.710637 -0.327818 -0.679653
# 53528070  0.329023  0.166345  0.573505  0.118089 -0.666395  0.288359
# 29505294 -0.152341 -0.440282 -0.053919 -0.780050 -0.439488 -0.269041
# 11671755 -0.503201  0.108246  0.473082 -0.286683 -0.019037 -0.188786
# 2584497  -0.020689 -0.554780 -0.338052  0.298405  0.013819 -0.176081
#
#                6         7         8         9    ...       758       759  \
# paper_id                                          ...
# 11214925  0.487536 -0.111532 -0.221759  1.076926  ...  0.273735 -1.289609
# 53528070  0.251724  0.257365  1.195837 -0.006816  ...  0.701276 -0.342759
# 29505294 -0.070937  0.657364  0.426640  0.853507  ...  0.900510 -0.236073
# 11671755  0.126679 -0.450921 -0.263748  0.663962  ... -0.028991 -1.347930
# 2584497  -0.330970 -0.025593  0.292353  0.593056  ...  0.383108 -1.140716
#
#                760       761       762       763       764       765  \
# paper_id
# 11214925  0.318137  0.259074 -0.247382 -0.393005  0.090319 -0.090303
# 53528070  0.020176  0.485454 -0.080130 -0.301968  0.153407 -0.353529
# 29505294 -0.097973  0.764468 -0.566981 -0.150950 -0.158955 -0.509435
# 11671755 -0.313984  0.643784  0.620243  0.362887  1.083892 -0.349423
# 2584497   1.002366  1.530569 -0.287538 -0.613112  0.544735 -0.538864
#
#                766       767
# paper_id
# 11214925  0.679653 -0.011298
# 53528070 -0.597097  0.030847
# 29505294 -0.552927  0.261767
# 11671755  0.519446  0.328365
# 2584497  -1.171622  0.134746
#
# [5 rows x 768 columns]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (804, 768)
# (804, 840)

# %%
#Create train set and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

# %%
#Create train set and validation set
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=1)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (614, 768)
# (614, 840)

# %% [markdown]
# # NN Model

# %%
batch_size = 256
num_classes = Y_train.shape[1]
epochs = 100

# %%
Y_test.shape
# Out:
# (121, 840)

# %%
embedding_dim = X_train.shape[1]

model = Sequential()
model.add(Dense(256, input_dim=embedding_dim, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               196864
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 840)               215880
# =================================================================
# Total params: 412,744
# Trainable params: 412,744
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=10)
history = model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[es],
                    validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0263 - accuracy: 0.0016 - val_loss: 0.0251 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0254 - accuracy: 0.0000e+00 - val_loss: 0.0250 - val_accuracy: 0.0145
# Epoch 3/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0251 - accuracy: 0.0033 - val_loss: 0.0249 - val_accuracy: 0.0145
# Epoch 4/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0248 - accuracy: 0.0081 - val_loss: 0.0248 - val_accuracy: 0.0145
# Epoch 5/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0245 - accuracy: 0.0098 - val_loss: 0.0247 - val_accuracy: 0.0145
# Epoch 6/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0241 - accuracy: 0.0114 - val_loss: 0.0245 - val_accuracy: 0.0145
# Epoch 7/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0237 - accuracy: 0.0098 - val_loss: 0.0244 - val_accuracy: 0.0145
# Epoch 8/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0233 - accuracy: 0.0098 - val_loss: 0.0243 - val_accuracy: 0.0145
# Epoch 9/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0228 - accuracy: 0.0179 - val_loss: 0.0241 - val_accuracy: 0.0145
# Epoch 10/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0223 - accuracy: 0.0309 - val_loss: 0.0239 - val_accuracy: 0.0145
# Epoch 11/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0220 - accuracy: 0.0277 - val_loss: 0.0237 - val_accuracy: 0.0145
# Epoch 12/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0213 - accuracy: 0.0228 - val_loss: 0.0235 - val_accuracy: 0.0145
# Epoch 13/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0208 - accuracy: 0.0423 - val_loss: 0.0233 - val_accuracy: 0.0145
# Epoch 14/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0202 - accuracy: 0.0521 - val_loss: 0.0231 - val_accuracy: 0.0290
# Epoch 15/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0197 - accuracy: 0.0603 - val_loss: 0.0230 - val_accuracy: 0.0290
# Epoch 16/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0191 - accuracy: 0.0765 - val_loss: 0.0229 - val_accuracy: 0.0290
# Epoch 17/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0186 - accuracy: 0.0847 - val_loss: 0.0227 - val_accuracy: 0.0290
# Epoch 18/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0180 - accuracy: 0.0831 - val_loss: 0.0225 - val_accuracy: 0.0145
# Epoch 19/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0175 - accuracy: 0.1173 - val_loss: 0.0223 - val_accuracy: 0.0435
# Epoch 20/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0170 - accuracy: 0.0993 - val_loss: 0.0222 - val_accuracy: 0.0290
# Epoch 21/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0164 - accuracy: 0.1238 - val_loss: 0.0220 - val_accuracy: 0.0290
# Epoch 22/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0159 - accuracy: 0.1303 - val_loss: 0.0217 - val_accuracy: 0.0290
# Epoch 23/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0152 - accuracy: 0.1401 - val_loss: 0.0216 - val_accuracy: 0.0290
# Epoch 24/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0149 - accuracy: 0.1580 - val_loss: 0.0214 - val_accuracy: 0.0435
# Epoch 25/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0143 - accuracy: 0.1401 - val_loss: 0.0213 - val_accuracy: 0.0435
# Epoch 26/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0142 - accuracy: 0.1759 - val_loss: 0.0212 - val_accuracy: 0.0290
# Epoch 27/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0138 - accuracy: 0.1938 - val_loss: 0.0210 - val_accuracy: 0.0290
# Epoch 28/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0132 - accuracy: 0.1938 - val_loss: 0.0209 - val_accuracy: 0.0290
# Epoch 29/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0129 - accuracy: 0.2134 - val_loss: 0.0209 - val_accuracy: 0.0145
# Epoch 30/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0126 - accuracy: 0.2313 - val_loss: 0.0208 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0121 - accuracy: 0.2427 - val_loss: 0.0208 - val_accuracy: 0.0290
# Epoch 32/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0119 - accuracy: 0.2459 - val_loss: 0.0208 - val_accuracy: 0.0145
# Epoch 33/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0116 - accuracy: 0.2508 - val_loss: 0.0208 - val_accuracy: 0.0435
# Epoch 34/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0111 - accuracy: 0.2622 - val_loss: 0.0207 - val_accuracy: 0.0435
# Epoch 35/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0111 - accuracy: 0.2590 - val_loss: 0.0207 - val_accuracy: 0.0145
# Epoch 36/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0109 - accuracy: 0.2850 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 0.2655 - val_loss: 0.0208 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0102 - accuracy: 0.3143 - val_loss: 0.0208 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 0.2899 - val_loss: 0.0209 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0100 - accuracy: 0.2557 - val_loss: 0.0209 - val_accuracy: 0.0145
# Epoch 41/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0099 - accuracy: 0.2948 - val_loss: 0.0209 - val_accuracy: 0.0145
# Epoch 42/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0094 - accuracy: 0.3029 - val_loss: 0.0209 - val_accuracy: 0.0145
# Epoch 43/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 0.3257 - val_loss: 0.0209 - val_accuracy: 0.0145
# Epoch 44/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0092 - accuracy: 0.3176 - val_loss: 0.0210 - val_accuracy: 0.0145
# Epoch 45/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0091 - accuracy: 0.3046 - val_loss: 0.0210 - val_accuracy: 0.0290
# Epoch 46/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 0.3290 - val_loss: 0.0211 - val_accuracy: 0.0290

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

fig, ax = plt.subplots(1,1, figsize=(10,6))

ax.plot(epochs, acc, 'r', label='Training acc')
ax.plot(epochs, val_acc, 'b', label='Validation acc')
ax.set_title('Accuracy', fontsize=18)
ax.set_xlabel(r'Epochs', fontsize=18)
ax.set_ylabel(r'Accuracy', fontsize=18)
ax.tick_params(labelsize=18)
ax.legend(fontsize=20)

plt.show()

figL, axL = plt.subplots(1,1, figsize=(10,6))

axL.plot(epochs, loss, 'r', label='Training loss')
axL.plot(epochs, val_loss, 'b', label='Validation loss')
axL.set_title('Loss', fontsize=18)
axL.set_xlabel(r'Epochs', fontsize=18)
axL.set_ylabel(r'Loss', fontsize=18)
axL.tick_params(labelsize=18)
axL.legend(fontsize=20)

plt.show()

# %% [markdown]
# # Model Evaluation with Information Retrieval Metrics

# %%
from src.metric_utils import MAP_score
from src.metric_utils import Recall_score

# %%
#Get probabilities for each citation
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# %%
train_MAP, test_MAP = MAP_score(Y_train, Y_test, train_predictions, test_predictions, top_k=5)

print("Training MAP Score: ", train_MAP)
print("Test MAP Score: ", test_MAP)
# Out:
# Training MAP Score:  0.493825099529497
# Test MAP Score:  0.12455463728191002

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=10)

print("Training Recall Score @10:", train_recall)
print("Test Recall Score @10:", test_recall)
# Out:
# Training Recall Score @10: 0.9972946073108939
# Test Recall Score @10: 0.3353994490358127

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=20)

print("Training Recall Score @20:", train_recall)
print("Test Recall Score @20:", test_recall)
# Out:
# Training Recall Score @20: 0.9994571118349619
# Test Recall Score @20: 0.42768595041322316

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=50)

print("Training Recall Score @50:", train_recall)
print("Test Recall Score @50:", test_recall)
# Out:
# Training Recall Score @50: 1.0
# Test Recall Score @50: 0.5919651056014693

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=100)

print("Training Recall Score @100:", train_recall)
print("Test Recall Score @100:", test_recall)
# Out:
# Training Recall Score @100: 1.0
# Test Recall Score @100: 0.713200183654729
