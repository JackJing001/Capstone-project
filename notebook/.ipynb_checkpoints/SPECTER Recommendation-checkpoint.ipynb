# %%
import os
import pandas as pd
import numpy as np

from collections import Counter
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Input
from sklearn.model_selection import train_test_split
from keras.utils import np_utils

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_pickle('../dataset/SS/clean/withlabel_SPECTER.pkl')
df.head()
# Out:
#                                                        title  \
# paper_id
# 859921     Summarizing Reviews with Variable-length Synta...
# 129124     Can Document Selection Help Semi-supervised Le...
# 1345235    Optimizing Sparse Matrix–Vector Product Comput...
# 2624639    Enhanced Chosen-Ciphertext Security and Applic...
# 146120525  ARSM: Augment-REINFORCE-Swap-Merge Estimator f...
#
#                                                     abstract  \
# paper_id
# 859921     Abstract. We present a novel summarization fra...
# 129124     Annotating training data for event extraction ...
# 1345235    Large-scale scientific applications frequently...
# 2624639    We introduce and study a new notion of enhance...
# 146120525  To address the challenge of backpropagating th...
#
#                                             relatedwork_text  \
# paper_id
# 859921     We first look at how text excerpts are extract...
# 129124     Self-training has been applied to several natu...
# 1345235    A variety of different data and computation re...
# 2624639    ECCA is similar in spirit to coin-revealing se...
# 146120525  For optimizing (1) for categorical z, the diff...
#
#                                                    main_text  \
# paper_id
# 859921     Abstract. We present a novel summarization fra...
# 129124     Annotating training data for event extraction ...
# 1345235    Large-scale scientific applications frequently...
# 2624639    We introduce and study a new notion of enhance...
# 146120525  To address the challenge of backpropagating th...
#
#                                                 rw_citations  \
# paper_id
# 859921          [5965756, 1599046, 3177797, 444032, 6884774]
# 129124     [1398439, 7419156, 11187670, 8336242, 15894892...
# 1345235    [1794629, 9580801, 120335238, 15090599, 208582...
# 2624639           [41204165, 19655, 235427, 226828, 3148885]
# 146120525  [3535369, 5859948, 1758804, 10756562, 19115634...
#
#                                               full_citations  \
# paper_id
# 859921     [1599046, 11055565, 16393334, 2481864, 5965756...
# 129124     [1398439, 7419156, 7579604, 11187670, 8336242,...
# 1345235    [1794629, 9580801, 120335238, 15090599, 208582...
# 2624639    [443317, 41204165, 7113862, 10098664, 226828, ...
# 146120525  [121929631, 4043645, 5859948, 7195970, 1075656...
#
#                                           SPECTER_embeddings label
# paper_id
# 859921     [-0.7218136, 0.99761677, -0.27647057, 0.235195...     2
# 129124     [-0.46521527, 0.17172785, 0.27331015, 0.088347...     2
# 1345235    [-0.16910633, 0.8334114, 0.039647657, -0.09229...     3
# 2624639    [0.12169194, 0.04154425, 0.2388953, 0.03814739...     1
# 146120525  [-0.8591176, 0.8032798, -0.012844058, 0.021643...     2

# %%
Counter(df['label'])
# Out:
# Counter({2: 4160, 3: 4914, 1: 4047, 0: 7807, 4: 6489})

# %%
df_cluster = df.loc[df.label == 0]
df_cluster.head()
# Out:
#                                                        title  \
# paper_id
# 42490916   Person Re-Identification as Image Retrieval Us...
# 54439672   Revisiting the Softmax Bellman Operator: Theor...
# 27941462   HapRing: A Wearable Haptic Device for 3D Inter...
# 53873286   Evaluating reinforcement learning state repres...
# 213175531     Pedestrian Detection: The Elephant In The Room
#
#                                                     abstract  \
# paper_id
# 42490916   Person re-identification is a challenging prob...
# 54439672   The softmax function has been primarily employ...
# 27941462   Haptic devices have the capability to offer go...
# 53873286   Reinforcement learning has shown potential for...
# 213175531  Pedestrian detection is used in many vision ba...
#
#                                             relatedwork_text  \
# paper_id
# 42490916   Person Re-identification A lot of methods have...
# 54439672   Among variants of the DQN in Mnih et al. (2015...
# 27941462   Preliminary research on finger-worn devices ex...
# 53873286   Many research studies have recognized and disp...
# 213175531  Pedestrian detection. Before the emergence of ...
#
#                                                    main_text  \
# paper_id
# 42490916   Person re-identification is a challenging prob...
# 54439672   The softmax function has been primarily employ...
# 27941462   Haptic devices have the capability to offer go...
# 53873286   Reinforcement learning has shown potential for...
# 213175531  Pedestrian detection is used in many vision ba...
#
#                                                 rw_citations  \
# paper_id
# 42490916   [11864530, 3961724, 16510219, 6485959, 7973738...
# 54439672   [5389801, 205242740, 19135734, 13022595, 68753...
# 27941462   [1749365, 207178608, 11112792, 10569979, 15182...
# 53873286   [4949646, 44019896, 18049436, 29073892, 538732...
# 213175531  [16824129, 14020880, 206590483, 206764948, 291...
#
#                                               full_citations  \
# paper_id
# 42490916   [14678946, 425268, 11864530, 14457153, 9107599...
# 54439672   [14530441, 13022595, 10713737, 5389801, 198118...
# 27941462   [1749365, 59860781, 207178608, 11112792, 10569...
# 53873286   [44019896, 10523205, 208910339, 18533192, 1537...
# 213175531  [1547290, 206787478, 7820575, 206764948, 19534...
#
#                                           SPECTER_embeddings label
# paper_id
# 42490916   [-1.0266498, 0.994633, 0.11097328, -0.20333652...     0
# 54439672   [-0.19075102, -0.69243807, 0.12877731, 0.69504...     0
# 27941462   [-0.2549635, 0.2130752, 0.90859884, -0.0577106...     0
# 53873286   [0.32041845, -0.055096526, 0.05453059, 0.33849...     0
# 213175531  [-0.3999968, 0.5237049, -0.19973156, -0.022197...     0

# %%
# Multi hot encoding for related works citations
mlb = MultiLabelBinarizer(sparse_output=True)

Y = pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(df_cluster['rw_citations']),
                index=df_cluster.index,
                columns=mlb.classes_)
Y.columns = Y.columns.astype(str)

# %%
Y.sum().value_counts()[0:20]
# Out:
# 1     26555
# 2      4854
# 3      1877
# 4      1023
# 5       547
# 6       380
# 7       270
# 8       200
# 9       144
# 10      117
# 12       95
# 11       69
# 13       68
# 15       41
# 14       38
# 16       34
# 18       21
# 17       19
# 20       17
# 19       17
# dtype: int64

# %%
Y.sum().value_counts()[3:].sum()
# Out:
# 3292

# %%
#Filter out papers that are not cited at least a few times
Y = Y[Y.columns[Y.sum() > 3]]
Y
# Out:
#            10004927  10005005  10012350  10024504  1003795  10044277  \
# paper_id
# 42490916          0         0         0         0        0         0
# 54439672          0         0         0         0        0         0
# 27941462          0         0         0         0        0         0
# 53873286          0         0         0         0        0         0
# 213175531         0         0         0         0        0         0
# ...             ...       ...       ...       ...      ...       ...
# 8425229           0         0         0         0        0         0
# 26037251          0         0         0         0        0         0
# 86772833          0         0         0         0        0         0
# 2966198           0         0         0         0        0         0
# 207660529         0         0         0         0        0         0
#
#            10048432  10053115  10054272  10057476  ...  9901844  9923122  \
# paper_id                                           ...
# 42490916          0         0         0         0  ...        0        0
# 54439672          0         0         0         0  ...        0        0
# 27941462          0         0         0         0  ...        0        0
# 53873286          0         0         0         0  ...        0        0
# 213175531         0         0         0         0  ...        0        0
# ...             ...       ...       ...       ...  ...      ...      ...
# 8425229           0         0         0         0  ...        0        0
# 26037251          0         0         0         0  ...        0        0
# 86772833          0         0         0         0  ...        0        0
# 2966198           0         0         0         0  ...        0        0
# 207660529         0         0         0         0  ...        0        0
#
#            9926549  9933254  9936656  9944232  9957731  996788  9971732  \
# paper_id
# 42490916         0        0        0        0        0       0        0
# 54439672         0        0        0        0        0       0        0
# 27941462         0        0        0        0        0       0        0
# 53873286         0        0        0        0        0       0        0
# 213175531        0        0        0        0        0       0        0
# ...            ...      ...      ...      ...      ...     ...      ...
# 8425229          0        0        0        0        0       0        0
# 26037251         0        0        0        0        0       0        0
# 86772833         0        0        0        0        0       0        0
# 2966198          0        0        0        0        0       0        0
# 207660529        0        0        0        0        0       0        0
#
#            9996719
# paper_id
# 42490916         0
# 54439672         0
# 27941462         0
# 53873286         0
# 213175531        0
# ...            ...
# 8425229          0
# 26037251         0
# 86772833         0
# 2966198          0
# 207660529        0
#
# [7807 rows x 3292 columns]

# %%
#Remove papers with less than 1 cited papers after filter
Y = Y.loc[Y.sum(axis=1) > 1]
Y.shape
# Out:
# (4801, 3292)

# %%
X = pd.DataFrame(df_cluster['SPECTER_embeddings'].to_list(), index= df_cluster.index)

#Filter out the same rows for predictive variables as well
X = X[X.index.isin(Y.index)]
X.head()
# Out:
#                 0         1         2         3         4         5    \
# paper_id
# 42490916  -1.026650  0.994633  0.110973 -0.203337  0.523484  0.236519
# 54439672  -0.190751 -0.692438  0.128777  0.695049 -0.192414  0.688506
# 213175531 -0.399997  0.523705 -0.199732 -0.022198 -0.326854  0.076296
# 9506814   -0.192253  0.675746  0.515082 -0.156564  0.562275  0.499302
# 3815098   -0.928529  0.923144 -0.278707  0.429758 -0.157087  0.753006
#
#                 6         7         8         9    ...       758       759  \
# paper_id                                           ...
# 42490916  -0.349746  0.482841  1.064224  0.850576  ...  0.602027  0.034141
# 54439672   1.116827  0.851380  0.696710  0.195115  ...  0.747377 -1.297828
# 213175531  0.096575 -0.044104  0.938657  0.969292  ... -0.156878 -0.065437
# 9506814    0.423574  0.400053  0.199794  0.202120  ...  1.057663 -0.162371
# 3815098    0.088561  0.222047  0.573633  0.156539  ...  0.907759 -0.427098
#
#                 760       761       762       763       764       765  \
# paper_id
# 42490916  -0.030774  0.388154  0.015196 -0.408135  0.700197 -0.115859
# 54439672   0.747788  0.666446 -0.611793 -0.146024  0.492655  0.685688
# 213175531  0.180335  0.012265 -0.334170 -0.638257  0.465312  0.236421
# 9506814    0.644905  0.144199 -0.194226 -0.951736 -0.021832 -0.490860
# 3815098    0.231713  0.969599 -0.287338 -0.112299  1.000033 -0.615851
#
#                 766       767
# paper_id
# 42490916   0.217704  0.516770
# 54439672  -0.473533  1.157149
# 213175531 -0.702101  0.507330
# 9506814   -0.431413  0.343492
# 3815098   -0.071888  0.152747
#
# [5 rows x 768 columns]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (4801, 768)
# (4801, 3292)

# %%
#Create train set and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

# %%
#Create train set and validation set
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=1)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (3672, 768)
# (3672, 3292)

# %% [markdown]
# # NN Model

# %%
batch_size = 256
num_classes = Y_train.shape[1]
epochs = 100

# %%
Y_test.shape
# Out:
# (721, 3292)

# %%
embedding_dim = X_train.shape[1]

model = Sequential()
model.add(Dense(768, input_dim=embedding_dim, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2000, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(4000, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 768)               590592
# _________________________________________________________________
# dropout (Dropout)            (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2000)              1538000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4000)              8004000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3292)              13171292
# =================================================================
# Total params: 23,303,884
# Trainable params: 23,303,884
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=15)
history = model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[es],
                    validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 15/15 [==============================] - 3s 167ms/step - loss: 0.0139 - accuracy: 0.0153 - val_loss: 0.0146 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.0134 - accuracy: 0.0305 - val_loss: 0.0142 - val_accuracy: 0.0368
# Epoch 3/100
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0129 - accuracy: 0.0398 - val_loss: 0.0136 - val_accuracy: 0.0368
# Epoch 4/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.0121 - accuracy: 0.0321 - val_loss: 0.0129 - val_accuracy: 0.0245
# Epoch 5/100
# 15/15 [==============================] - 2s 160ms/step - loss: 0.0112 - accuracy: 0.0373 - val_loss: 0.0123 - val_accuracy: 0.0245
# Epoch 6/100
# 15/15 [==============================] - 2s 152ms/step - loss: 0.0105 - accuracy: 0.0400 - val_loss: 0.0121 - val_accuracy: 0.0221
# Epoch 7/100
# 15/15 [==============================] - 2s 152ms/step - loss: 0.0099 - accuracy: 0.0455 - val_loss: 0.0119 - val_accuracy: 0.0221
# Epoch 8/100
# 15/15 [==============================] - 2s 154ms/step - loss: 0.0093 - accuracy: 0.0632 - val_loss: 0.0119 - val_accuracy: 0.0196
# Epoch 9/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.0088 - accuracy: 0.0727 - val_loss: 0.0119 - val_accuracy: 0.0270
# Epoch 10/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.0083 - accuracy: 0.0771 - val_loss: 0.0120 - val_accuracy: 0.0147
# Epoch 11/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.0078 - accuracy: 0.1016 - val_loss: 0.0121 - val_accuracy: 0.0196
# Epoch 12/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.0073 - accuracy: 0.1217 - val_loss: 0.0125 - val_accuracy: 0.0270
# Epoch 13/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.0070 - accuracy: 0.1332 - val_loss: 0.0126 - val_accuracy: 0.0270
# Epoch 14/100
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0066 - accuracy: 0.1590 - val_loss: 0.0129 - val_accuracy: 0.0196
# Epoch 15/100
# 15/15 [==============================] - 2s 152ms/step - loss: 0.0062 - accuracy: 0.1754 - val_loss: 0.0132 - val_accuracy: 0.0196
# Epoch 16/100
# 15/15 [==============================] - 2s 156ms/step - loss: 0.0060 - accuracy: 0.2034 - val_loss: 0.0132 - val_accuracy: 0.0196
# Epoch 17/100
# 15/15 [==============================] - 2s 158ms/step - loss: 0.0058 - accuracy: 0.2026 - val_loss: 0.0135 - val_accuracy: 0.0270
# Epoch 18/100
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0056 - accuracy: 0.1999 - val_loss: 0.0135 - val_accuracy: 0.0270
# Epoch 19/100
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0054 - accuracy: 0.2108 - val_loss: 0.0133 - val_accuracy: 0.0392
# Epoch 20/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.0052 - accuracy: 0.2249 - val_loss: 0.0135 - val_accuracy: 0.0294
# Epoch 21/100
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0051 - accuracy: 0.2309 - val_loss: 0.0137 - val_accuracy: 0.0221
# Epoch 22/100
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0050 - accuracy: 0.2326 - val_loss: 0.0137 - val_accuracy: 0.0294
# Epoch 23/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.0049 - accuracy: 0.2309 - val_loss: 0.0135 - val_accuracy: 0.0172

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

fig, ax = plt.subplots(1,1, figsize=(10,6))

ax.plot(epochs, acc, 'r', label='Training acc')
ax.plot(epochs, val_acc, 'b', label='Validation acc')
ax.set_title('Accuracy', fontsize=18)
ax.set_xlabel(r'Epochs', fontsize=18)
ax.set_ylabel(r'Accuracy', fontsize=18)
ax.tick_params(labelsize=18)
ax.legend(fontsize=20)

plt.show()

figL, axL = plt.subplots(1,1, figsize=(10,6))

axL.plot(epochs, loss, 'r', label='Training loss')
axL.plot(epochs, val_loss, 'b', label='Validation loss')
axL.set_title('Loss', fontsize=18)
axL.set_xlabel(r'Epochs', fontsize=18)
axL.set_ylabel(r'Loss', fontsize=18)
axL.tick_params(labelsize=18)
axL.legend(fontsize=20)

plt.show()

# %% [markdown]
# # Model Evaluation with Information Retrieval Metrics

# %%
from src.metric_utils import MAP_score
from src.metric_utils import Recall_score

# %%
#Get probabilities for each citation
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# %%
train_MAP, test_MAP = MAP_score(Y_train, Y_test, train_predictions, test_predictions, top_k=5)

print("Training MAP Score: ", train_MAP)
print("Test MAP Score: ", test_MAP)
# Out:
# Training MAP Score:  0.7175356299927378
# Test MAP Score:  0.09711319155493912

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=10)

print("Training Recall Score @10:", train_recall)
print("Test Recall Score @10:", test_recall)
# Out:
# Training Recall Score @10: 0.9548022544310277
# Test Recall Score @10: 0.19460872722047864

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=20)

print("Training Recall Score @20:", train_recall)
print("Test Recall Score @20:", test_recall)
# Out:
# Training Recall Score @20: 0.9907648435782863
# Test Recall Score @20: 0.2817857979229784

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=50)

print("Training Recall Score @50:", train_recall)
print("Test Recall Score @50:", test_recall)
# Out:
# Training Recall Score @50: 0.9981538958770657
# Test Recall Score @50: 0.42334645720214875

# %%
train_recall, test_recall = Recall_score(Y_train, Y_test, train_predictions, test_predictions, top_k=100)

print("Training Recall Score @100:", train_recall)
print("Test Recall Score @100:", test_recall)
# Out:
# Training Recall Score @100: 0.9992747080755308
# Test Recall Score @100: 0.5437519688508919
